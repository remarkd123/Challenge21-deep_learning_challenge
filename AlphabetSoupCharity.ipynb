# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
app_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
app_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
app_df = app_df.drop(columns=['EIN', 'NAME'])
app_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
app_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
apptype_counts = app_df.APPLICATION_TYPE.value_counts()
apptype_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(apptype_counts[apptype_counts<1000].index)

# Replace in dataframe
for app in application_types_to_replace:
    app_df['APPLICATION_TYPE'] = app_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
app_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_counts = app_df.CLASSIFICATION.value_counts()
class_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_counts_above1 = app_df.CLASSIFICATION.value_counts(>1)
class_counts
# Out:
#   File "<ipython-input-8-c038ad957abb>", line 2
#     class_counts_above1 = app_df.CLASSIFICATION.value_counts(>1)
#                                                              ^
# SyntaxError: invalid syntax

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_counts[class_counts<1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    app_df['CLASSIFICATION'] = app_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
app_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
# ohe_app_df = pd.get_dummies(data=app_df, columns=('APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE' ,'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS')
                            
app_with_dummies = pd.get_dummies(app_df)
app_with_dummies
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       1
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                         0                    0                    0
# 1                         0                    1                    0
# 2                         0                    0                    0
# 3                         0                    1                    0
# 4                         0                    1                    0
# ...                     ...                  ...                  ...
# 34294                     0                    0                    1
# 34295                     0                    0                    1
# 34296                     0                    1                    0
# 34297                     0                    0                    0
# 34298                     0                    1                    0
#
#        APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  AFFILIATION_CompanySponsored  \
# 0                        0                    0                             0
# 1                        0                    0                             0
# 2                        1                    0                             1
# 3                        0                    0                             1
# 4                        0                    0                             0
# ...                    ...                  ...                           ...
# 34294                    0                    0                             0
# 34295                    0                    0                             1
# 34296                    0                    0                             1
# 34297                    1                    0                             0
# 34298                    0                    0                             0
#
#        ...  INCOME_AMT_1-9999  INCOME_AMT_10000-24999  \
# 0      ...                  0                       0
# 1      ...                  1                       0
# 2      ...                  0                       0
# 3      ...                  0                       1
# 4      ...                  0                       0
# ...    ...                ...                     ...
# 34294  ...                  0                       0
# 34295  ...                  0                       0
# 34296  ...                  0                       0
# 34297  ...                  0                       0
# 34298  ...                  0                       0
#
#        INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  \
# 0                             0                   0                 0
# 1                             0                   0                 0
# 2                             0                   0                 0
# 3                             0                   0                 0
# 4                             1                   0                 0
# ...                         ...                 ...               ...
# 34294                         0                   0                 0
# 34295                         0                   0                 0
# 34296                         0                   0                 0
# 34297                         0                   0                 0
# 34298                         0                   0                 1
#
#        INCOME_AMT_25000-99999  INCOME_AMT_50M+  INCOME_AMT_5M-10M  \
# 0                           0                0                  0
# 1                           0                0                  0
# 2                           0                0                  0
# 3                           0                0                  0
# 4                           0                0                  0
# ...                       ...              ...                ...
# 34294                       0                0                  0
# 34295                       0                0                  0
# 34296                       0                0                  0
# 34297                       0                0                  0
# 34298                       0                0                  0
#
#        SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                             1                         0
# 1                             1                         0
# 2                             1                         0
# 3                             1                         0
# 4                             1                         0
# ...                         ...                       ...
# 34294                         1                         0
# 34295                         1                         0
# 34296                         1                         0
# 34297                         1                         0
# 34298                         1                         0
#
# [34299 rows x 41 columns]

# %%
# Split our preprocessed data into our features and target arrays
y=app_with_dummies.IS_SUCCESSFUL
X=app_with_dummies.drop(columns=["IS_SUCCESSFUL"])

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
features=len(X_train_scaled[0])
hidden_nodes1 = 80
hidden_nodes2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes1, input_dim=features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes2, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 80)                3280
#
#  dense_25 (Dense)            (None, 30)                2430
#
#  dense_26 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 5,741
# Trainable params: 5,741
# Non-trainable params: 0
# _________________________________________________________________

# %%
import os
import datetime as datetime
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model=nn.fit(X_train_scaled,y_train, epochs=100, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5737 - accuracy: 0.7215
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5571 - accuracy: 0.7311
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5545 - accuracy: 0.7315
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5524 - accuracy: 0.7332
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5509 - accuracy: 0.7337
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5510 - accuracy: 0.7330
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5499 - accuracy: 0.7331
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5490 - accuracy: 0.7341
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7355
# Epoch 10/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5477 - accuracy: 0.7338
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7338
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7344
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5468 - accuracy: 0.7351
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5463 - accuracy: 0.7352
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7368
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7355
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5454 - accuracy: 0.7365
# Epoch 18/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5455 - accuracy: 0.7374
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7356
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5446 - accuracy: 0.7366
# Epoch 21/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5446 - accuracy: 0.7365
# Epoch 22/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5446 - accuracy: 0.7370
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7372
# Epoch 24/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5437 - accuracy: 0.7384
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7366
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7380
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5435 - accuracy: 0.7385
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5435 - accuracy: 0.7387
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5432 - accuracy: 0.7365
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5432 - accuracy: 0.7386
# Epoch 31/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5427 - accuracy: 0.7376
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5430 - accuracy: 0.7377
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7376
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5427 - accuracy: 0.7381
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.7379
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7382
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7386
# Epoch 38/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5419 - accuracy: 0.7379
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7385
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7386
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7378
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7390
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7385
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7387
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5408 - accuracy: 0.7390
# Epoch 46/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5412 - accuracy: 0.7388
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5414 - accuracy: 0.7384
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7389
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7385
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7392
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7393
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5411 - accuracy: 0.7386
# Epoch 53/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5407 - accuracy: 0.7393
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7387
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5405 - accuracy: 0.7383
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5404 - accuracy: 0.7386
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7390
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5404 - accuracy: 0.7392
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5400 - accuracy: 0.7395
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5401 - accuracy: 0.7393
# Epoch 61/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5402 - accuracy: 0.7389
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5395 - accuracy: 0.7392
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5396 - accuracy: 0.7399
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7405
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5401 - accuracy: 0.7398
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7393
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7397
# Epoch 68/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5395 - accuracy: 0.7398
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7394
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5395 - accuracy: 0.7390
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5393 - accuracy: 0.7393
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7392
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5396 - accuracy: 0.7388
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5394 - accuracy: 0.7389
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7397
# Epoch 76/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5393 - accuracy: 0.7394
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5390 - accuracy: 0.7396
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7389
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7396
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5393 - accuracy: 0.7391
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5386 - accuracy: 0.7397
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7395
# Epoch 83/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5393 - accuracy: 0.7389
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5387 - accuracy: 0.7398
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7398
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7406
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7398
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5384 - accuracy: 0.7396
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7402
# Epoch 90/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5386 - accuracy: 0.7404
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7399
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7405
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5386 - accuracy: 0.7397
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7399
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5386 - accuracy: 0.7397
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7406
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7400
# Epoch 98/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5380 - accuracy: 0.7409
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7399
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7411

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5666 - accuracy: 0.7261 - 462ms/epoch - 2ms/step
# Loss: 0.566594660282135, Accuracy: 0.726064145565033

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")
